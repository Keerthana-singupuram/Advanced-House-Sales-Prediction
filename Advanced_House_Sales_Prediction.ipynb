# %% [markdown]
# <a href="https://colab.research.google.com/github/Keerthana-singupuram/Advanced-House-Sales-Prediction/blob/main/Advanced_House_Sales_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Avanced House Sales Prediction**
#
#
# Advanced House Sales Prediction Dashboard that gives analysis of best houses depending on various factors.
#
# **Dataset :**
# This dataset contains 1061 rows and 13 columns, in CSV format:
#
# Based on the below factors, the insights are obtained.
#
# Lot Area, Building Type, House Style, Overall Quality, Overall Condition, Year Built, Living Area, Fire Places, Garage Cars, Garage Area, Paved Drive, Sale Condition, Sale Price.
#
# Based on the above factors and recorded data, here is the analysis of Advanced House Sales.
#
# ![Maven upload - MS Excel Project 2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Summary:**
#
# It is observed that only 6 outstanding houses are present with high demand to purchase which are ancient historic constructions.
